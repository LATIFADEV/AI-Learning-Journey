# %%
# import pandas as pd
df = pd.read_csv("dataset.csv")
# import pandas as pd
# import numpy as np

# data = {
#     "Age": [25, 30, 35, 40, 45, 50],
#     "Glucose": [85, 90, np.nan, 110, 120, 130],
#     "BloodPressure": [70, np.nan, 80, 85, np.nan, 90],
#     "BMI": [22.5, 24.0, 25.0, np.nan, 28.0, 30.0],
#     "Insulin": [np.nan, 80, 90, 100, np.nan, 130]
# }

# df = pd.DataFrame(data)
import numpy as np

cols_to_replace = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

df[cols_to_replace] = df[cols_to_replace].replace(0, np.nan)

print(df)
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0             0            6    148.0           72.0           35.0      NaN
# 1             1            1     85.0           66.0           29.0      NaN
# 2             2            8    183.0           64.0            NaN      NaN
# 3             3            1     89.0           66.0           23.0     94.0
# 4             4            0    137.0           40.0           35.0    168.0
# ..          ...          ...      ...            ...            ...      ...
# 763         763           10    101.0           76.0           48.0    180.0
# 764         764            2    122.0           70.0           27.0      NaN
# 765         765            5    121.0           72.0           23.0    112.0
# 766         766            1    126.0           60.0            NaN      NaN
# 767         767            1     93.0           70.0           31.0      NaN
#
#       BMI  DiabetesPedigreeFunction  Age
# ...

# %%
print(df.head())
print(df.info())
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6    148.0           72.0           35.0      NaN
# 1           1            1     85.0           66.0           29.0      NaN
# 2           2            8    183.0           64.0            NaN      NaN
# 3           3            1     89.0           66.0           23.0     94.0
# 4           4            0    137.0           40.0           35.0    168.0
#
#     BMI  DiabetesPedigreeFunction  Age
# 0  33.6                     0.627   50
# 1  26.6                     0.351   31
# 2  23.3                     0.672   32
# 3  28.1                     0.167   21
# 4  43.1                     2.288   33
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                768 non-null    int64
# ...

# %%
print(df.shape)      # dimensions
print(df.describe()) # statistiques
# Out:
# (768, 9)
#        Unnamed: 0  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# count  768.000000   768.000000  763.000000     733.000000     541.000000
# mean   383.500000     3.845052  121.686763      72.405184      29.153420
# std    221.846794     3.369578   30.535641      12.382158      10.476982
# min      0.000000     0.000000   44.000000      24.000000       7.000000
# 25%    191.750000     1.000000   99.000000      64.000000      22.000000
# 50%    383.500000     3.000000  117.000000      72.000000      29.000000
# 75%    575.250000     6.000000  141.000000      80.000000      36.000000
# max    767.000000    17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction         Age
# count  394.000000  757.000000                768.000000  768.000000
# mean   155.548223   32.457464                  0.471876   33.240885
# std    118.775855    6.924988                  0.331329   11.760232
# ...

# %%
# Valeurs manquantes
print(df.isnull().sum())
# Out:
# Unnamed: 0                    0
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
# doublons 
print(df.duplicated().sum())
# Out:
# 0

# %%
# doublons 
df = df.drop_duplicates()

# %%
# Distrebution des valeurs 
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(figsize=(10,8))
plt.show()

# %%
print(df.skew())
# Out:
# Unnamed: 0                  0.000000
# Pregnancies                 0.901674
# Glucose                     0.530989
# BloodPressure               0.134153
# SkinThickness               0.690619
# Insulin                     2.166464
# BMI                         0.593970
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# dtype: float64

# %%
for col in df.columns:
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
corr = df.corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
# Prétraitement des données
# Gestion des valeurs manquantes
# Cas 1 : supprimer
df = df.dropna()
print(df)
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 3             3            1     89.0           66.0           23.0     94.0
# 4             4            0    137.0           40.0           35.0    168.0
# 6             6            3     78.0           50.0           32.0     88.0
# 8             8            2    197.0           70.0           45.0    543.0
# 13           13            1    189.0           60.0           23.0    846.0
# ..          ...          ...      ...            ...            ...      ...
# 753         753            0    181.0           88.0           44.0    510.0
# 755         755            1    128.0           88.0           39.0    110.0
# 760         760            2     88.0           58.0           26.0     16.0
# 763         763           10    101.0           76.0           48.0    180.0
# 765         765            5    121.0           72.0           23.0    112.0
#
#       BMI  DiabetesPedigreeFunction  Age
# ...

# %%
# Cas 2 : moyenne / médiane
df.fillna(df.mean(), inplace=True)
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 3             3            1     89.0           66.0           23.0     94.0
# 4             4            0    137.0           40.0           35.0    168.0
# 6             6            3     78.0           50.0           32.0     88.0
# 8             8            2    197.0           70.0           45.0    543.0
# 13           13            1    189.0           60.0           23.0    846.0
# ..          ...          ...      ...            ...            ...      ...
# 753         753            0    181.0           88.0           44.0    510.0
# 755         755            1    128.0           88.0           39.0    110.0
# 760         760            2     88.0           58.0           26.0     16.0
# 763         763           10    101.0           76.0           48.0    180.0
# 765         765            5    121.0           72.0           23.0    112.0
#
#       BMI  DiabetesPedigreeFunction  Age
# ...

# %%
# Cas 3 : interpolation (séries)
df.interpolate(inplace=True)
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 3             3            1     89.0           66.0           23.0     94.0
# 4             4            0    137.0           40.0           35.0    168.0
# 6             6            3     78.0           50.0           32.0     88.0
# 8             8            2    197.0           70.0           45.0    543.0
# 13           13            1    189.0           60.0           23.0    846.0
# ..          ...          ...      ...            ...            ...      ...
# 753         753            0    181.0           88.0           44.0    510.0
# 755         755            1    128.0           88.0           39.0    110.0
# 760         760            2     88.0           58.0           26.0     16.0
# 763         763           10    101.0           76.0           48.0    180.0
# 765         765            5    121.0           72.0           23.0    112.0
#
#       BMI  DiabetesPedigreeFunction  Age
# ...

# %%
# Cas 4 : KNN 
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
df_imputed = imputer.fit_transform(df)

df = pd.DataFrame(df_imputed, columns=df.columns)
print(df)
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           3.0          1.0     89.0           66.0           23.0     94.0
# 1           4.0          0.0    137.0           40.0           35.0    168.0
# 2           6.0          3.0     78.0           50.0           32.0     88.0
# 3           8.0          2.0    197.0           70.0           45.0    543.0
# 4          13.0          1.0    189.0           60.0           23.0    846.0
# ..          ...          ...      ...            ...            ...      ...
# 387       753.0          0.0    181.0           88.0           44.0    510.0
# 388       755.0          1.0    128.0           88.0           39.0    110.0
# 389       760.0          2.0     88.0           58.0           26.0     16.0
# 390       763.0         10.0    101.0           76.0           48.0    180.0
# 391       765.0          5.0    121.0           72.0           23.0    112.0
#
#       BMI  DiabetesPedigreeFunction   Age
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
