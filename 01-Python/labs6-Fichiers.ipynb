# %%
# Créer et écrire dans un fichier
with open("notea.txt", "w") as f:
    f.write("test")

# %%
with open("notea.txt", "r") as f:
    print(f.readline())
# Out:
# test

# %%
import os

print(os.getcwd())
# Out:
# C:\WINDOWS\system32\AI

# %%
import os

chemin = os.path.join("dossier", "fichier.txt")
print(chemin)
# Out:
# dossier\fichier.txt

# %%
import os

chemin = os.path.join("dossier", "fichier.txt")
print(chemin)
# Out:
# dossier\fichier.txt

# %%
import os

os.chdir("dossier")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import os
#       2
# ----> 3 os.chdir("dossier")
#
# FileNotFoundError: [WinError 2] Le fichier spécifié est introuvable: 'dossier'
